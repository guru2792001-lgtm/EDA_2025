# %% [markdown]
# ## **- Under EDA**
#
# **- Data Analysis**
#      - Quick Checks
#      - how to select the column
#      - we understood the difference bet df vs series vs values
#      - Frequency Table
#      - bar charts
#      - pie charts
#      - histogram
#      - Distribution plots
#      - outliers
#      - Deal with Outliers
#      - bi variate analysis
#      - multivairate analysis
#      - heatmaps
# **- Feature enginearing**
#      - Encoding
#      - Scaling
#      - Transformation
# **- Feature selection(How to select important features)**

# %% [markdown]
# **Encoding**
#
# - convert catagorical data to numerical data
# - ML algorithem developed by maths
# - maths needs numbers
# - it is very important we need to convert categorical data to numerical
#   - map
#   - np.where
#   - LabelEncoder
#   - OneHotcoder

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=df1.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ## **Map Method**

# %%
df1['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
dict1={'Certified':0,'Denied':1}
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
df1['case_status_map']=df1['case_status'].map(dict1)

# %%
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
dict2={'Africa':0,'Asia':1,'Europe':3,'North America':4,'Oceania':5,'South America':6}
dict2
# Out:
# {'Africa': 0,
#  'Asia': 1,
#  'Europe': 3,
#  'North America': 4,
#  'Oceania': 5,
#  'South America': 6}

# %%
df1['continent_map']=df1['continent'].map(dict2)

# %%
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns

# %%
cat=df1.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
labels=df1['continent'].unique()
d={}
for i in range(len(labels)):
    d[labels[i]]=i

d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
labels=df1['continent'].unique()
d={labels[i]:i for i in range(len(labels))}
df1['continent']=df1['continent'].map(d)
df1
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
df1,cat,num
# Out:
# (         case_id continent education_of_employee has_job_experience  \
#  0         EZYV01      Asia           High School                  N
#  1         EZYV02      Asia              Master's                  Y
#  2         EZYV03      Asia            Bachelor's                  N
#  3         EZYV04      Asia            Bachelor's                  N
#  4         EZYV05    Africa              Master's                  Y
#  ...          ...       ...                   ...                ...
#  25475  EZYV25476      Asia            Bachelor's                  Y
#  25476  EZYV25477      Asia           High School                  Y
#  25477  EZYV25478      Asia              Master's                  Y
#  25478  EZYV25479      Asia              Master's                  Y
#  25479  EZYV25480      Asia            Bachelor's                  Y
#
#        requires_job_training  no_of_employees  yr_of_estab  \
#  0                         N            14513         2007
# ...

# %%
for i in cat[1:]:
    labels=df1[i].unique()
    d={labels[i]:i for i in range(len(labels))}
    df1[i]=df1[i].map(d)
df1
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## **LabelEncoder**

# %%
import sklearn
sklearn
# Out:
# <module 'sklearn' from 'C:\\Users\\pguru\\anaconda3\\Lib\\site-packages\\sklearn\\__init__.py'>

# %%
# Step-1 import the package
from sklearn.preprocessing import LabelEncoder
#step-2 save the package
le=LabelEncoder()
# step-3 fit and fit_transform
le.fit_transform(df1['case_status'])

# fit means finding the some values
# transforms means: transform apply those values
#
# Out:
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['case_data']=le.fit_transform(df1['case_status'])
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['continent']=le.fit_transform(df1['continent'])
df1
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['region_of_employment']=le.fit_transform(df1['region_of_employment'])
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:
    df1[i]=le.fit_transform(df1[i])
df1
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## **OnehotEncoder**

# %% [markdown]
# ## **pd.get_dummies**

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
pd.get_dummies(df1,dtype=int)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
cols=cat[1:]
df2=pd.get_dummies(df1,columns=cols,dtype=int)
df2
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %%
from sklearn.preprocessing import StandardScalar
ss=StandardScalar()
df1['continent']=ss.fit_transform(df1['continent'])
df1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from sklearn.preprocessing import StandardScalar
#       2 ss=StandardScalar()
#       3 df1['continent']=ss.fit_transform(df1['continent'])
#
# ImportError: cannot import name 'StandardScalar' from 'sklearn.preprocessing' (C:\Users\pguru\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %% [markdown]
# - Before model Development
#
# - We will do EDA: Exploratary data anlysis
#   - Feature(columns)analysis
#      - Categorical,Numerical, Outliers analysis, Bivariate, Multivarite
#      - We will get the insight
#   - Feature Engineering
#      - we will modify the the data
#      - Models developed by maths
#      - Encoding : Convert categorical data to Numerical Variables
#      - Scaling : All the numerical columns makes under one scale
#      - Transformations : All the maths developed by assumption data follows distribution
#        - convert skewed distribution to Normal
#   - Feature selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sns

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ## **Map Method
#
# - create a dictionary labels as keys, numbers a values
# - in python index start with 0
# - Case status has two labels we need two values 0 and 1
# - Certified becomes 0
# - Denied becomes 1

# %%
df1['case_status'].nunique()
# Out:
# 2

# %%
df1['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
df1['case_status']=df1['case_status'].map(d)

# %%
d
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
labels=df1['continent'].unique()
d={}
for i in range(len(labels)):
    d[labels[i]]=i

d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
labels=df1['continent'].unique()
d={labels[i]:i for i in range(len(labels))}
    #Key             #value
df1['continent']=df1['continent'].map(d)

# %%
df1
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
for i in cat[1:]:
    labels=df1[i].unique()
    d={labels[i]:i for i in range(len(labels))}
    df1[i]=df1[i].map(d)
df1
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# ## **prepare  all methods in one notes**
#
# - Fequency table
# - subplot using for loop
# -

# %% [markdown]
# ## **LabelIEncoder**
#
# - Sickit-learn(sklearn)
# - sklearn library is a heart of machine learning in python
# - mLlib is heart of machine learning in pyspark
# - sklearn (library)
#    - preprocess (Class)
#       - LabelEncoder(Method)
#
# - fit : calculate something
# - fit_transform : we are modify the values because of calculated one

# %%
df1=pd.read_csv(r"F:\Omkar_sir_files\CSV_Files\Visadataset (1).csv")
cat=df1.select_dtypes(include='object').columns
num=df1.select_dtypes(exclude='object').columns
from sklearn.preprocessing import LabelEncoder #read the method  
le=LabelEncoder()                       #save the method
le.fit_transform(df1['case_status'])  # apply fit transform
# Out:
# array([1, 0, 1, ..., 0, 0, 0])
