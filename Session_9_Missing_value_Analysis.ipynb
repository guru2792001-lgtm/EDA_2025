# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suesh','Satish',np.nan],
      'Age':[np.nan,22,25,27],
      'City':['Pune','Pune',np.nan,'Hyd']}
df=pd.DataFrame(Data)
df
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0  None
# 3    None  27.0   Hyd

# %%
df.to_csv('data_missing.csv',index=False)

# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suesh','Satish',None],
      'Age':[None,22,25,27],
      'City':['Pune','Pune',None,'Hyd']}
df1=pd.DataFrame(Data)
df1
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0  None
# 3    None  27.0   Hyd

# %%
df1.to_csv('data_missing.csv',index=False)

# %%
df1.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %% [markdown]
# ## **isnull**

# %%
df.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df1.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df1.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df.fillna(30)#not recomandent
# Out:
#     Names   Age  City
# 0  Ramesh  30.0  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0    30
# 3      30  27.0   Hyd

# %% [markdown]
# ## **what is the difference between np.nan and None**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,np.nan,3])
arr2=np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1)
# Out:
# 6.0

# %%
np.sum(arr1)
# Out:
# nan

# %%
np.nansum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 np.nansum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:723, in nansum(a, axis, dtype, out, keepdims, initial, where)
#     626 """
#     627 Return the sum of array elements over a given axis treating Not a
#     628 Numbers (NaNs) as zero.
#    (...)    720
#     721 """
#     722 a, mask = _replace_nan(a, 0)
# --> 723 return np.sum(a, axis=axis, dtype=dtype, out=out, keepdims=keepdims,
#     724               initial=initial, where=where)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# ...

# %%
np.sum(arr2)

# %% [markdown]
# - np,nan reperesented **float type**
# - None represented **object type**
# - if data operations related to Maths then nan format is better

# %% [markdown]
# ## **Fill the value based on column**

# %%
#df.filna

# %% [markdown]
# - pad
# - bfill
# - ffill
# - backfill

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad')
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
df.fillna(method='bfill')
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %%
df.fillna(method='ffill')
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
df.fillna(method='backfill')
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %%
df.fillna(method='pad',axis=1)
# Out:
#     Names     Age  City
# 0  Ramesh  Ramesh  Pune
# 1   Suesh    22.0  Pune
# 2  Satish    25.0  25.0
# 3     NaN    27.0   Hyd

# %%
df.fillna(method='bfill',axis=1)
# Out:
#     Names   Age  City
# 0  Ramesh  Pune  Pune
# 1   Suesh  22.0  Pune
# 2  Satish  25.0   NaN
# 3    27.0  27.0   Hyd

# %% [markdown]
# ## **Mean-Median_Mode**

# %%
idea-1: filling with random value = df.fillname(<random valuea>)
idea-2: filling with rv bsed on column=df[<col>].fillname(<random valuea>)
idea-3: filling with some pattern using a method: df.fillna(<method>)
idea-4: filling with m-m-m based on column=df[<col>].fillname(<mean> or <median> or <mode>)
idea-5: filling with avg value only selected nighbours
idea-5: filling with a based
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 age_mean=data1['Age'].mean()
#
# NameError: name 'data1' is not defined

# %%
data1=df

# %%
age_mean=data1['Age'].mean()
print('age_mean:',age_mean)
data1['Age'].fillna(age_mean)
# Out:
# age_mean: 24.666666666666668
# 0    24.666667
# 1    22.000000
# 2    25.000000
# 3    27.000000
# Name: Age, dtype: float64

# %%
city_mode.values[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 city_mode.values[0]
#
# NameError: name 'city_mode' is not defined

# %% [markdown]
# - in future sometimes if we direct impute mode value we will get error
# - mode is comming as series
# - mean is coming as fixed value
# - so first convert series to fixed

# %% [markdown]
# ## **impute class**

# %% [markdown]
# - under the sklearn we have impute class is there

# %% [markdown]
# <!-- from sklearn import impute -->

# %%
from sklearn import impute

# %% [markdown]
# ## **KNM Immputer**
#
# - k- Nearest Neighbour
# - where k= hyper parameter which means the user can change
# - idea: instead of taking all the samples average
#     - First fix the neighbour number i.e k
#     - Then find the neighbours using distance metric
#     - then take the average of those samples to fill the missing value

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer=KNMImputer(n_neighbors=2,weights='distance')
imputer.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 4
#       2 from sklearn.impute import KNNImputer
#       3 X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
# ----> 4 imputer=KNMImputer(n_neighbors=2,weights='distance')
#       5 imputer.fit_transform(X)
#
# NameError: name 'KNMImputer' is not defined

# %%
import numpy as np
from sklearn.impute import KNNImputer

# Sample data with missing values
X = [[1, 2, np.nan], [3, np.nan, 3], [np.nan, 60, 5], [8, 8, 7]]

# Create the KNN imputer
imputer = KNNImputer(n_neighbors=2, weights='distance')

# Fit the imputer and transform the data
X_imputed = imputer.fit_transform(X)

print(X_imputed)
# Out:
# [[ 1.          2.          3.93905505]
#  [ 3.         31.          3.        ]
#  [ 3.25775362 60.          5.        ]
#  [ 8.          8.          7.        ]]

# %%
import pandas as pd
import numpy as np

# %%
dict1={'Name':['Ramesh','Suresh','Satish',np.nan],
       'Age':[30,33,np.nan,36],
       'City':[np.nan,'Hyd','bel','blr']
      }

# %%
df=pd.DataFrame(dict1)
df
# Out:
#      Name   Age City
# 0  Ramesh  30.0  NaN
# 1  Suresh  33.0  Hyd
# 2  Satish   NaN  bel
# 3     NaN  36.0  blr

# %%
df.to_csv('data_missings.csv',index=False)

# %%
df.isnull().sum()
# Out:
# Name    1
# Age     1
# City    1
# dtype: int64

# %% [markdown]
# ## **dropna**
#
# - drop  the null values data based on rows and columns

# %%
#i want to extract the data with out null values
df.dropna()
# Out:
#      Name   Age City
# 1  Suresh  33.0  Hyd

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
dict1={'Name':['Ramesh','Suresh','Satish',np.nan],
       'Age':[30,33,np.nan,36],
       'City':[np.nan,'Hyd','bel','blr'],
       'Compony':['Google','Microsoft','Apple','Meta']
      }
df1=pd.DataFrame(dict1)
df1
# Out:
#      Name   Age City    Compony
# 0  Ramesh  30.0  NaN     Google
# 1  Suresh  33.0  Hyd  Microsoft
# 2  Satish   NaN  bel      Apple
# 3     NaN  36.0  blr       Meta

# %%
df1.fillna(30)
# Out:
#      Name   Age City    Compony
# 0  Ramesh  30.0   30     Google
# 1  Suresh  33.0  Hyd  Microsoft
# 2  Satish  30.0  bel      Apple
# 3      30  36.0  blr       Meta

# %%
df1['Name'].fillna('Manish')
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# 3    Manish
# Name: Name, dtype: object

# %% [markdown]
# **Draw back:is not good
#
# - TO Avoid we have some methods
#   - backfill
#   - bfill
#   - ffill
#   - pad

# %%
import warnings
warnings.filterwarnings('ignore')
df1.fillna(method='pad')
# Out:
#      Name   Age City    Compony
# 0  Ramesh  30.0  NaN     Google
# 1  Suresh  33.0  Hyd  Microsoft
# 2  Satish  33.0  bel      Apple
# 3  Satish  36.0  blr       Meta

# %%
import warnings
warnings.filterwarnings('ignore')
df1.fillna(method='pad',axis=1)
# Out:
#      Name     Age  City    Compony
# 0  Ramesh    30.0  30.0     Google
# 1  Suresh    33.0   Hyd  Microsoft
# 2  Satish  Satish   bel      Apple
# 3     NaN    36.0   blr       Meta

# %%
import warnings
warnings.filterwarnings('ignore')
df1.fillna(method='ffill')
# Out:
#      Name   Age City    Compony
# 0  Ramesh  30.0  NaN     Google
# 1  Suresh  33.0  Hyd  Microsoft
# 2  Satish  33.0  bel      Apple
# 3  Satish  36.0  blr       Meta

# %%
import warnings
warnings.filterwarnings('ignore')
df1.fillna(method='bfill')
# Out:
#      Name   Age City    Compony
# 0  Ramesh  30.0  Hyd     Google
# 1  Suresh  33.0  Hyd  Microsoft
# 2  Satish  36.0  bel      Apple
# 3     NaN  36.0  blr       Meta

# %% [markdown]
# ## **Mean-Median-Mode**

# %% [markdown]
# - numerical:mean or median
# - categorical= mode
# - outlier= media

# %%
age_mean=df1['Age'].mean()
print('age_mean:',age_mean)
df1['Age'].fillna(age_mean)
# Out:
# age_mean: 33.0
# 0    30.0
# 1    33.0
# 2    33.0
# 3    36.0
# Name: Age, dtype: float64

# %%
city_model=df1['City'].mode()
city_model.values[0]
# Out:
# 'Hyd'

# %% [markdown]
# ## **impute class**

# %% [markdown]
# - under the we have impute class is there

# %%
from sklearn import impute

# %%
dir(impute)
# Out:
# ['KNNImputer',
#  'MissingIndicator',
#  'SimpleImputer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_knn',
#  'typing']

# %%
- distance method in ml
- euclidian
- jaccord or jacobian
- manhattan
- Cosine===RAG   where to use and how to use i want formula i want aplication where will use 
- find the relation betn

# %%
import numpy as np
from sklearn.impute import KNNImputerimport numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer=KNMImputer(n_neighbors=2,weights='distance')
imputer.fit_transform(X)
